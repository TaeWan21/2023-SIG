# %%
import pandas as pd
df = pd.read_csv('/Users/kimtaewan/Desktop/2023 겨울SIG/개인및관계.csv')
df.head()
# Out:
#          header.dialogueInfo.dialogueID  \
# 0  451a86a0-a699-5c49-9370-e1d79ea63506
# 1  79643c13-82b6-52fd-b780-e9aa1c86bbf8
# 2  0c176655-d84a-5c1f-be6b-1aa3a47aa79c
# 3  17d398fe-dbf4-5eb5-a476-c99419f28423
# 4  4ae65aa9-8568-5872-a325-cede2e1ac02a
#
#    header.dialogueInfo.numberOfParticipants  \
# 0                                         2
# 1                                         2
# 2                                         2
# 3                                         2
# 4                                         2
#
#    header.dialogueInfo.numberOfUtterances  header.dialogueInfo.numberOfTurns  \
# 0                                      20                                  8
# 1                                       9                                  6
# 2                                      10                                  5
# 3                                      13                                  9
# ...

# %%
import pandas as pd
df = pd.read_csv('/Users/kimtaewan/Desktop/2023 겨울SIG/개인및관계.csv')
df = df['body.dialogue']['utterance']
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 3
#       1 import pandas as pd
#       2 df = pd.read_csv('/Users/kimtaewan/Desktop/2023 겨울SIG/개인및관계.csv')
# ----> 3 df = df['body.dialogue']['utterance']
#       4 df
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/series.py:1116, in Series._get_value(self, label, takeable)
# ...
